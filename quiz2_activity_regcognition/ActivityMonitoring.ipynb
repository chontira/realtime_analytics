# %%
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# Load data
data = pd.read_csv('dataset/Running.csv', sep=',',  names=["time_ms", "x", "y","z"])
print(len(data))

# Plot
plt.figure(figsize = (15,4), dpi=100)
plt.subplot(311)
plt.plot(data['time_ms'],data['x'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('x')

plt.subplot(312)
plt.plot(data['time_ms'],data['y'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('y')

plt.subplot(313)
plt.plot(data['time_ms'],data['z'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('z')

plt.show()
# Out:
# 716

# %%
# Load data
data = pd.read_csv('dataset/standing_new.csv', sep=',',  names=["time_ms", "x", "y","z"])
print(len(data))

# Plot
plt.figure(figsize = (15,4), dpi=100)
plt.subplot(311)
plt.plot(data['time_ms'],data['x'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('x')

plt.subplot(312)
plt.plot(data['time_ms'],data['y'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('y')

plt.subplot(313)
plt.plot(data['time_ms'],data['z'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('z')

plt.show()
# Out:
# 76

# %%
# Load data
data = pd.read_csv('dataset/Walking_1616323148861.csv', sep=',',  names=["time_ms", "x", "y","z"])
print(len(data))

# Plot
plt.figure(figsize = (15,4), dpi=100)
plt.subplot(311)
plt.plot(data['time_ms'],data['x'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('x')

plt.subplot(312)
plt.plot(data['time_ms'],data['y'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('y')

plt.subplot(313)
plt.plot(data['time_ms'],data['z'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('z')

plt.show()
# Out:
# 1488

# %%
# Load data
data = pd.read_csv('dataset/walking_new.csv', sep=',',  names=["time_ms", "x", "y","z"])
print(len(data))

# Plot
plt.figure(figsize = (15,4), dpi=100)
plt.subplot(311)
plt.plot(data['time_ms'],data['x'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('x')

plt.subplot(312)
plt.plot(data['time_ms'],data['y'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('y')

plt.subplot(313)
plt.plot(data['time_ms'],data['z'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('z')

plt.show()
# Out:
# 90

# %%
# Load data
data = pd.read_csv('dataset/Running_1616323397867.csv', sep=',',  names=["time_ms", "x", "y","z"])
print(len(data))

# Plot
plt.figure(figsize = (15,4), dpi=100)
plt.subplot(311)
plt.plot(data['time_ms'],data['x'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('x')

plt.subplot(312)
plt.plot(data['time_ms'],data['y'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('y')

plt.subplot(313)
plt.plot(data['time_ms'],data['z'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('z')

plt.show()
# Out:
# 1599

# %%
# Load data
data = pd.read_csv('dataset/running_new.csv', sep=',',  names=["time_ms", "x", "y","z"])
print(len(data))

# Plot
plt.figure(figsize = (15,4), dpi=100)
plt.subplot(311)
plt.plot(data['time_ms'],data['x'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('x')

plt.subplot(312)
plt.plot(data['time_ms'],data['y'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('y')

plt.subplot(313)
plt.plot(data['time_ms'],data['z'])
#plt.plot(data['time_ms'][300:320],data['y'][300:320])
#plt.xticks(data['time_ms'][300:320])
plt.xlabel('time (ms)')
plt.ylabel('z')

plt.show()
# Out:
# 105
